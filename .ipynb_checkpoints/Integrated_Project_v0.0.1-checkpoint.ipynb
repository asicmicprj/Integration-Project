# %% [markdown]
# # Integration Project #1

# %% [markdown]
# # Table of contents

# %% [markdown]
# 1. [Project Description](#ProjectDescription)
# 2. [Step 1: Open data and general information](#OpenData&GeneralInfo)
# 3.   [* Step 1: Conclusion](#GeneranlInfoConclusion)
# 4. [Step 2: Prepare the Data](#PrepareData)
# 5. [* To Do List](#Step2ToDoList)
# 6.  [* Step 2: Conclusion](#Step2Conclusion)
# 7. [Step 3: Analyze the data](#AnalyzeData)
# 8. [* To Do List](#Step3ToDoList)
# 9.  [* Step 3: Conclusion](#Step3Conclusion)
# 10. [Step 4: Create User Profile for each region](#Step4UserProfile)
# 11. [* To Do List](#Step4ToDoList)
# 12.  [* Step 4: Conclusion](#Step4Conclusion)
# 13. [Step 5: Test the following hypotheses](#Step5Hypotheses)
# 14. [Step 6: Write a general conclusion](#GeneralConclusion)

# %% [markdown]
# ### Project Description. <a name="ProjectDescription"></a>

# %% [markdown]
# |  Name  |  Description  |
# | :----: |  :---- |
# |  **Initial conditions**  | You work for the online store Ice, which sells video games all over the world. User and expert reviews, genres, platforms (e.g. Xbox or PlayStation), and historical data on game sales are available from open sources.  |
# |  **Main question of project**  |  What patterns will show that the game will be successful?|
# | **Project Description**  | [Link to Project Description](https://practicum.yandex.com/learn/data-scientist/courses/c1a0fd14-8873-4755-8885-68fd987bf001/sprints/4250/topics/96ff1466-eef1-46cf-9e43-33b1632b3b5a/lessons/6ac0f71f-9759-4e3d-bcc7-e59143954858/)    |
# | **Datasets**             | [/datasets/games.csv](https://code.s3.yandex.net/datasets/games.csv)  |

# %% [markdown]
# ### Step 1. Open the data file and study the general information. <a name="OpenData&GeneralInfo"></a>

# %%
# import all packages
import pandas as pd
import numpy as np
import random
from scipy import stats as st

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

# %matplotlib inline

# %%
# connect all datasets:
df_games = pd.read_csv('https://code.s3.yandex.net/datasets/games.csv')

# %%
# function to determine if columns in file have null values:
def get_percent_of_na(df, num):
    count = 0; # first reset counter.
    df = df.copy() # copy dataframe in new structure.
    amount = (df.isna().sum() / df.shape[0])
    
    for column, percent in zip(amount.index, amount.values):
        num_of_nulls = df[column].isna().sum()
        if num_of_nulls == 0:
            continue
        else:
            count += 1
        print('Column {} has {:.{}%} percent of Nulls, and {} of nulls'.format(column, percent, num, num_of_nulls))
        
    if count != 0:
        print('\033[1m' + 'There are {} columns with NA.'.format(count) + '\033[0m')
    else: 
        print()
        print('\033[1m' + 'There are no columns with NA.' + '\033[0m')

# %%
def get_percent_of_na_table(df, num):
    df_nulls = pd.DataFrame(df.isna().sum(), columns=['Missing Values'])
    df_nulls['Percent of Nulls'] = round(df_nulls['Missing Values'] / df.shape[0], num) * 100
    return df_nulls

# %%
# function to display helpfull information about each file.
def get_info(df):
    print('Head:')
    display(df.head())
    print('-'*110)
    
    print('Info:')
    display(df.info())
    print('-'*110)
    
    print('Describe:')
    display(df.describe())
    display(df.describe(include='object'))
    print('-'*110)
    
    #print('Columns with nulls:')
    #get_percent_of_na(df_games, 2)
    #print('-'*110)
    
    print('Percent of columns with nulls:')
    display(get_percent_of_na_table(df_games, 2))
    print('-'*110)
    
    print('Shape:')
    print(df.shape)
    print('-'*110)
    
    print('Duplicated:')
    print('\033[1m' + 'We have {} duplicated rows. \n'.format(df.duplicated().sum()) + '\033[0m')
    print('/'*110)

# %%
# let's use get_info function for check information for all datasets:
get_info(df_games)
# Out:
# Head:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN
# --------------------------------------------------------------------------------------------------------------
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB
# None
# --------------------------------------------------------------------------------------------------------------
# Describe:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000
#                                Name Platform   Genre User_Score Rating
# count                         16713    16715   16713      10014   9949
# unique                        11559       31      12         96      8
# top     Need for Speed: Most Wanted      PS2  Action        tbd      E
# freq                             12     2161    3369       2424   3990
# --------------------------------------------------------------------------------------------------------------
# Percent of columns with nulls:
#                  Missing Values  Percent of Nulls
# Name                          2               0.0
# Platform                      0               0.0
# Year_of_Release             269               2.0
# Genre                         2               0.0
# NA_sales                      0               0.0
# EU_sales                      0               0.0
# JP_sales                      0               0.0
# Other_sales                   0               0.0
# Critic_Score               8578              51.0
# User_Score                 6701              40.0
# Rating                     6766              40.0
# --------------------------------------------------------------------------------------------------------------
# Shape:
# (16715, 11)
# --------------------------------------------------------------------------------------------------------------
# Duplicated:
# We have 0 duplicated rows.
#
# //////////////////////////////////////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# #### Step1: Conclusion <a name="GeneranlInfoConclusion"></a>

# %% [markdown]
# Based on the above information:
# > * A very large percentage of missing values in a column "Critic_Score" - 51%. More than half of the data is missing.
# * Columns "User_Score" and "Raiting" also have approximately the same percentage of missing data: 40%.
# * We can calculate the average for a column "Critic_Score" because the values in that column are of type real to fill in the missing values.
# * Columns "User_Score" and "Rating" are of type object.

# %% [markdown]
# ### Step 2. Prepare the data <a name="PrepareData"></a>

# %% [markdown]
# #### To-Do List: <a name="Step2ToDoList"></a>

# %% [markdown]
# > - [X] Replace the column names (make them lowercase).
# - [X] Convert the data to the required types.
# - [X] Describe the columns where the data types have been changed and why.
# - [X] If necessary, decide how to deal with missing values:
# - [X] Explain why you filled in the missing values as you did or why you decided to leave them blank.
# - [X] Why do you think the values are missing? Give possible reasons.
# - [X] Pay attention to the abbreviation TBD (to be determined). Specify how you intend to handle such cases.
# - [X] Calculate the total sales (the sum of sales in all regions) for each game and put these values in a separate column.

# %% [markdown]
# - [X] Replace the column names (make them lowercase).

# %%
def lowercase_convert(df):
    return df.rename(str.lower, axis='columns')
df_games = lowercase_convert(df_games)
print(df_games.columns)
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# - [X] Convert the data to the required types.

# %%
# check again columns data type.
df_games.info()
df_games.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# * Column "year_of_release" should be an integer, currently it is a float.
# * Column "user_score" should be a float, currently it is a object.

# %% [markdown]
# Before need to put attention, to this point:
# - Pay attention to the abbreviation TBD (to be determined). Specify how you intend to handle such cases.

# %%
# replase all "tbd" values by na in column "user_score".
df_games['user_score'].replace(['tbd'], np.nan, inplace=True)

# %%
# describe type convertation function
def convert_to_type(df, columns, type_val):
    for col in columns:
        df[col] = df[col].astype(type_val)
        
# and fill nan by mean values function.
def fill_nan(df, columns):
    for col in columns:
        df[col] = df[col].fillna(df[col].mean())

# %%
# use this functions:
# first convert "user_score" column -> float type.
convert_to_type(df_games, ['user_score'], float)
# fill missing values of "critic_score" and "user_score" by mean values.
fill_nan(df_games,['critic_score','user_score'])
df_games.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 0     28.96      3.77         8.45     76.000000    8.000000      E
# 1      3.58      6.81         0.77     68.967679    7.125046    NaN
# 2     12.76      3.79         3.29     82.000000    8.300000      E
# 3     10.93      3.28         2.95     80.000000    8.000000      E
# 4      8.89     10.22         1.00     68.967679    7.125046    NaN

# %%
# fill missing values of 'year_of_release' column by median values.
df_games['rating'].fillna('NA', inplace=True)
df_games['year_of_release'].fillna(df_games['year_of_release'].median(), inplace=True)

# %%
# convert other types.
convert_to_type(df_games, ['name','platform','genre','rating'], str)
convert_to_type(df_games, ['year_of_release'], int)
convert_to_type(df_games, ['na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'critic_score', 'user_score'], float)
# check types of data again
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16715 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  int32
#  3   genre            16715 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     16715 non-null  float64
#  9   user_score       16715 non-null  float64
#  10  rating           16715 non-null  object
# dtypes: float64(6), int32(1), object(4)
# memory usage: 1.3+ MB

# %%
# now replace all missing values by value "Not Avaiable" in column 'rating'
df_games['rating'] = df_games['rating'].replace(['NA'], np.nan)
# let's create merge dictionary "genre-rating":
dict_genre_rating = df_games.groupby('genre')['rating'].agg(pd.Series.mode).to_dict()
print(dict_genre_rating)
# Out:
# {'Action': 'T', 'Adventure': 'E', 'Fighting': 'T', 'Misc': 'E', 'Platform': 'E', 'Puzzle': 'E', 'Racing': 'E', 'Role-Playing': 'T', 'Shooter': 'M', 'Simulation': 'E', 'Sports': 'E', 'Strategy': 'T', 'nan': array([], dtype=object)}

# %%
df_games['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %%
df_games['rating'].value_counts()
# Out:
# E       3990
# T       2961
# M       1563
# E10+    1420
# EC         8
# K-A        3
# RP         3
# AO         1
# Name: rating, dtype: int64

# %%
#write function for fill missing values in column "rating"
def fill_rating(row):
    if row['rating'] is np.nan or row['rating'] == '[]':
        return dict_genre_rating[row['genre']]
    else:
        return row['rating']
    
df_games['rating'] = df_games.apply(fill_rating, axis=1)
df_games['rating'].value_counts()
# Out:
# E       7793
# T       5618
# M       1867
# E10+    1420
# EC         8
# K-A        3
# RP         3
# []         2
# AO         1
# Name: rating, dtype: int64

# %%
# let's check again missing values.
df_games.isna().sum()
# Out:
# name               0
# platform           0
# year_of_release    0
# genre              0
# na_sales           0
# eu_sales           0
# jp_sales           0
# other_sales        0
# critic_score       0
# user_score         0
# rating             0
# dtype: int64

# %% [markdown]
# all missing values filled.

# %% [markdown]
# - [X] Calculate the total sales (the sum of sales in all regions) for each game and put these values in a separate column.

# %%
df_games.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %%
df_games['total_sales'] = df_games[['na_sales','eu_sales','jp_sales','other_sales']].sum(axis=1)
df_games['total_sales'].head()
# Out:
# 0    82.54
# 1    40.24
# 2    35.52
# 3    32.77
# 4    31.38
# Name: total_sales, dtype: float64

# %% [markdown]
# #### Step 2: Conclusion <a name="Step2Conclusion"></a>

# %% [markdown]
# **In step 2 it was implemented:**
# > * Column names have been changed to lowercase.
# * Corresponding data types for some columns have been changed. Data type of column **"user_score"** changed to float. Prior to this, this column was of type object, although it included only numeric values. Column **"year_of release"** was changed to integer type from float. The real type is redundant for the values of this column.
# * Missing values have been filled, for column "year_of_release" - by median values. I was guided to take the most recurring year. For columns **'critic_score','user_score'** - the missing values have been filled in with the mean value.
# * In columns **'critic_score', 'user_score'** may have missing values as the columns are populated by critics and viewers. In all of them, they can be omitted because users did not provide values.
# * I decided to replace the abbreviation TBD (to be determined) - by nan values.
# * Created new column **'total_sales'** based on columns **na_sales, eu_sales, jp_sales, other_sales**.

# %% [markdown]
# ### Step 3. Analyze the data <a name="AnalyzeData"></a>

# %% [markdown]
# #### To-Do List: <a name="Step3ToDoList"></a>

# %% [markdown]
# > - [X] Look at how many games were released in different years. Is the data for every period significant?
# - [X] Look at how sales varied from platform to platform. Choose the platforms with the greatest total sales and build a distribution based on data for each year. Find platforms that used to be popular but now have zero sales. How long does it generally take for new platforms to appear and old ones to fade?
# - [X] Determine what period you should take data for. To do so, look at your answers to the previous questions. The data should allow you to build a prognosis for 2017.
# - [X] Work only with the data that you've decided is relevant. Disregard the data for previous years.
# - [X] Which platforms are leading in sales? Which ones are growing or shrinking? Select several potentially profitable platforms.
# - [X] Build a box plot for the global sales of all games, broken down by platform. Are the differences in sales significant? What about average sales on various platforms? Describe your findings.
# - [X] Take a look at how user and professional reviews affect sales for one popular platform (you choose). Build a scatter plot and calculate the correlation between reviews and sales. Draw conclusions.
# - [X] Keeping your conclusions in mind, compare the sales of the same games on other platforms.
# - [X] Take a look at the general distribution of games by genre. What can we say about the most profitable genres? Can you generalize about genres with high and low sales?

# %% [markdown]
# - [X] Look at how many games were released in different years. Is the data for every period significant?

# %%
# for check how many games were released in different years, we can group by years_of_release and count this values. 
display(df_games.groupby('year_of_release')['name'].agg('count'))
# Out:
# year_of_release
# 1980       9
# 1981      46
# 1982      36
# 1983      17
# 1984      14
# 1985      14
# 1986      21
# 1987      16
# 1988      15
# 1989      17
# 1990      16
# 1991      41
# 1992      43
# 1993      62
# 1994     121
# 1995     219
# 1996     263
# 1997     289
# 1998     379
# 1999     338
# 2000     350
# 2001     482
# 2002     829
# 2003     775
# 2004     762
# 2005     939
# 2006    1006
# 2007    1466
# 2008    1427
# 2009    1426
# 2010    1255
# 2011    1136
# 2012     653
# 2013     544
# 2014     581
# 2015     606
# 2016     502
# Name: name, dtype: int64

# %%
# let's render this data.
def render_data_plot(df, column):
    bins     = np.arange(df[column].min(),df[column].max()+1,3)
    bar_plot = df.groupby(pd.cut(df[column], bins=bins)).agg({column:'count'})
    ax       = bar_plot.plot(kind='bar', rot=45, figsize=(12,4), legend=False)
    for i, value in enumerate(bar_plot.iloc[:,0].values):
        ax.text(i + 0.25, value + 3, str(value), color='blue', fontweight='bold')
    plt.ylabel('count')
    plt.show()

# %%
render_data_plot(df_games, 'year_of_release')

# %% [markdown]
# Conclusion:
# > * According to the graph, we can see that the maximum number of games was released between 2007 and 2010. During this period, 4108 games were released. In subsequent years, the number of games released began to decline, and very sharply, the next four years from 2010 to 2013 showed that 2333 games were released. Which means a reduction in the release of the game by almost 2 times. This almost corresponds to the time span from 2001 to 2004, when the market was growing - 2366 games released.
# * If this is a negative trend, then the number of games in subsequent periods of time should not increase.

# %% [markdown]
# - [X] Look at how sales varied from platform to platform. Choose the platforms with the greatest total sales and build a distribution based on data for each year. Find platforms that used to be popular but now have zero sales. How long does it generally take for new platforms to appear and old ones to fade?

# %%
def render_plot_bar(df, x, y, column='', value='', func=np.sum):
    if column != '' and value != '':
        filter_df      = df[df[column] == value]
        plot_df        = filter_df.pivot_table(index=x, values=y, aggfunc=func)
        values_to_plot = plot_df[y].values
    else:
        plot_df        = df.pivot_table(index=x, values=y, aggfunc=func)
        values_to_plot = plot_df[y].values
        
    title = str(value) + " - " + str(y) + ' vs. ' + x
    ax    = plot_df.plot(kind='bar', figsize=(16,5), rot=45, title=title, legend=False)
    
    for i in ax.patches: 
        ax.annotate(str(round(i.get_height(), 2)), (i.get_x() * 1.005, i.get_height() * 1.05))
    
    plt.ylabel(y)
    plt.show()

# %%
sales = df_games.pivot_table(index='platform', values='total_sales', aggfunc=np.sum).sort_values(by='total_sales', ascending=False).head()
display(sales)
# Out:
#           total_sales
# platform
# PS2           1255.77
# X360           971.42
# PS3            939.65
# Wii            907.51
# DS             806.12

# %%
for platform in df_games['platform'].unique():
    render_plot_bar(df_games, 'year_of_release', 'total_sales', 'platform', platform)

# %% [markdown]
# Descriptions and conclusion:
# > * The most popular releases per platform are:
#      1. PS2 -	\$1255.77
#      1. X360 -	\$971.42
#      1. PS3	- \$939.65
#      1. Wii	- \$907.51
#      1. DS	- \$806.12
#
# > * After about 1 year, the console will gain popularity.
# * Typical lifespan of concolse is around 4-6 years.
# * One of the platforms that has been popular is the NES platform. It was quite popular from 1983 to 1988, but her last year of sales dates back to 1994. Thus, for 2016, it has zero sales now.

# %% [markdown]
# - [X] Determine what period you should take data for. To do so, look at your answers to the previous questions. The data should allow you to build a prognosis for 2017.

# %%
df_years_slice = df_games[(df_games['year_of_release'] >= 2006) & (df_games['year_of_release'].notnull())]
df_years_slice.head()
# Out:
#                     name platform  year_of_release     genre  na_sales  \
# 0             Wii Sports      Wii             2006    Sports     41.36
# 2         Mario Kart Wii      Wii             2008    Racing     15.68
# 3      Wii Sports Resort      Wii             2009    Sports     15.61
# 6  New Super Mario Bros.       DS             2006  Platform     11.28
# 7               Wii Play      Wii             2006      Misc     13.96
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      E
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 6      9.14      6.50         2.88          89.0         8.5      E
# 7      9.18      2.93         2.84          58.0         6.6      E
#
#    total_sales
# 0        82.54
# 2        35.52
# 3        32.77
# 6        29.80
# 7        28.91

# %% [markdown]
# Conclusion:
# > * I decided to choose the period from 2006 to 2016, since it was from 2006 that the number of games released per year began to number in the thousands.

# %% [markdown]
# - [X] Which platforms are leading in sales? Which ones are growing or shrinking? Select several potentially profitable platforms.

# %%
df_years_slice.pivot_table(index='platform', values='total_sales', aggfunc='sum').sort_values(by='total_sales', ascending=False).head(6)
# Out:
#           total_sales
# platform
# X360           963.17
# PS3            939.65
# Wii            907.51
# DS             658.69
# PS4            314.14
# PS2            288.01

# %%
# render this data: 
for platform in ['X360', 'PS3', 'Wii', 'DS', 'PS4', '3DS']:
    render_plot_bar(df_games, 'year_of_release','total_sales','platform', platform)

# %% [markdown]
# Conclusion:
# > * Most profitable console is the X360, PS3 and Wii, according to current total_sales indicators.
# * At the moment, all platform sales are declining.
# * But according to the typical life span of platforms, I would additionally pay attention to the PS4 platform. At the moment, this platform looks the best in terms of sales for 2016.

# %% [markdown]
# - [X] Build a box plot for the global sales of all games, broken down by platform. Are the differences in sales significant? What about average sales on various platforms? Describe your findings.

# %%
# let's games from most profitable consols: 
df_ps3  = df_games.query('platform == "PS3"')
df_xbox = df_games.query('platform == "X360"')
df_ps4  = df_games.query('platform == "PS4"')

# %%
display(df_ps3.sort_values(by='total_sales', ascending=False).head())
print('-' *124)
display(df_ps3.sort_values(by='total_sales', ascending=False).tail())
# Out:
#                               name platform  year_of_release    genre  \
# 16              Grand Theft Auto V      PS3             2013   Action
# 34      Call of Duty: Black Ops II      PS3             2012  Shooter
# 37  Call of Duty: Modern Warfare 3      PS3             2011  Shooter
# 41         Call of Duty: Black Ops      PS3             2010  Shooter
# 54                  Gran Turismo 5      PS3             2010   Racing
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16      7.02      9.09      0.98         3.96          97.0         8.2
# 34      4.99      5.73      0.65         2.42          83.0         5.3
# 37      5.54      5.73      0.49         1.57          88.0         3.2
# 41      5.99      4.37      0.48         1.79          88.0         6.4
# 54      2.96      4.82      0.81         2.11          84.0         7.5
#
#    rating  total_sales
# 16      M        21.05
# 34      M        13.79
# 37      M        13.33
# 41      M        12.63
# 54      E        10.70
# ----------------------------------------------------------------------------------------------------------------------------
#                                               name platform  year_of_release  \
# 16241                                       NHL 16      PS3             2015
# 16274  Sega Golf Club: Miyazato San Kyoudai Naizou      PS3             2006
# 16283                             Toro to Morimori      PS3             2009
# 16710                Samurai Warriors: Sanada Maru      PS3             2016
# 16676                             G1 Jockey 4 2008      PS3             2008
#
#         genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 16241  Sports       0.0      0.01      0.00          0.0     68.967679
# 16274  Sports       0.0      0.00      0.01          0.0     68.967679
# 16283    Misc       0.0      0.00      0.01          0.0     68.967679
# 16710  Action       0.0      0.00      0.01          0.0     68.967679
# 16676  Sports       0.0      0.00      0.00          0.0     68.967679
#
#        user_score rating  total_sales
# 16241    7.125046      E         0.01
# 16274    7.125046      E         0.01
# 16283    7.125046      E         0.01
# 16710    7.125046      T         0.01
# 16676    7.125046      E         0.00

# %%
plt.figure(figsize=(16,5))
sns.distplot(df_ps3['total_sales'])
plt.show()

plt.figure(figsize=(16,5))
sns.boxplot(df_ps3['total_sales'])
plt.show()

# %%
display(df_ps4.sort_values(by='total_sales', ascending=False).head())
print('-' *124)
display(df_ps4.sort_values(by='total_sales', ascending=False).tail())
# Out:
#                               name platform  year_of_release    genre  \
# 31       Call of Duty: Black Ops 3      PS4             2015  Shooter
# 42              Grand Theft Auto V      PS4             2014   Action
# 77                         FIFA 16      PS4             2015   Sports
# 87    Star Wars Battlefront (2015)      PS4             2015  Shooter
# 92  Call of Duty: Advanced Warfare      PS4             2014  Shooter
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 31      6.03      5.86      0.36         2.38     68.967679    7.125046
# 42      3.96      6.31      0.38         1.97     97.000000    8.300000
# 77      1.12      6.12      0.06         1.28     82.000000    4.300000
# 87      2.99      3.49      0.22         1.28     68.967679    7.125046
# 92      2.81      3.48      0.14         1.23     83.000000    5.700000
#
#    rating  total_sales
# 31      M        14.63
# 42      M        12.62
# 77      E         8.58
# 87      M         7.98
# 92      M         7.66
# ----------------------------------------------------------------------------------------------------------------------------
#                                     name platform  year_of_release  \
# 15943           Professional Farmer 2016      PS4             2015
# 15864  Rocksmith 2014 Edition Remastered      PS4             2016
# 15839         Mark McMorris Infinite Air      PS4             2016
# 15790                   This War of Mine      PS4             2016
# 16585      Farming 2017 - The Simulation      PS4             2016
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 15943      Action      0.00      0.01       0.0          0.0     68.967679
# 15864        Misc      0.01      0.00       0.0          0.0     68.967679
# 15839      Sports      0.01      0.00       0.0          0.0     49.000000
# 15790      Action      0.00      0.01       0.0          0.0     68.967679
# 16585  Simulation      0.00      0.01       0.0          0.0     68.967679
#
#        user_score rating  total_sales
# 15943    7.125046      T         0.01
# 15864    7.800000      T         0.01
# 15839    6.000000      T         0.01
# 15790    7.125046      T         0.01
# 16585    7.125046      E         0.01

# %%
plt.figure(figsize=(16,5))
sns.distplot(df_ps4['total_sales'])
plt.show()

plt.figure(figsize=(16,5))
sns.boxplot(df_ps4['total_sales'])
plt.show()

# %% [markdown]
# > * Significant difference in numbers between the best-selling game for the PS3 platform (Grand Theft Auto V, total sales: 21.05 thousand dollars) -  and the most unpopular game (for example - NHL 16, total sales: 1 thousand dollars).
# * Special case, PS4 platform: most popular - Call of Duty: Black Ops 3, total sales: 14.63 thousand dollars, and the most unpopular game - Professional Farmer 2016, total sales: 1 thousand dollars.

# %% [markdown]
# - [X] Take a look at how user and professional reviews affect sales for one popular platform (you choose). Build a scatter plot and calculate the correlation between reviews and sales. Draw conclusions.

# %%
display(df_ps3['critic_score'].describe())
print('-' *124)
display(df_ps3['user_score'].describe())
# Out:
# count    1331.000000
# mean       69.839582
# std        11.041423
# min        13.000000
# 25%        68.967679
# 50%        68.967679
# 75%        76.000000
# max        98.000000
# Name: critic_score, dtype: float64
# ----------------------------------------------------------------------------------------------------------------------------
# count    1331.000000
# mean        6.862488
# std         1.200849
# min         0.200000
# 25%         6.700000
# 50%         7.125046
# 75%         7.400000
# max         9.100000
# Name: user_score, dtype: float64

# %% [markdown]
# From our project description, we know that:
# — Critic_Score (maximum of 100)
# — User_Score (maximum of 10)

# %%
# possible to created combined score: (user_score + critic_score / 10(scale)) divided by 2. 
df_ps3['combined_score'] = (df_ps3.loc[:,'user_score'] + (df_ps3.loc[:,'critic_score'] / 10.0)) / 2.0 
df_ps4['combined_score'] = (df_ps4.loc[:,'user_score'] + (df_ps4.loc[:,'critic_score'] / 10.0)) / 2.0
# Out:
# <ipython-input-107-f582de761de9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ps3['combined_score'] = (df_ps3.loc[:,'user_score'] + (df_ps3.loc[:,'critic_score'] / 10.0)) / 2.0
# <ipython-input-107-f582de761de9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ps4['combined_score'] = (df_ps4.loc[:,'user_score'] + (df_ps4.loc[:,'critic_score'] / 10.0)) / 2.0

# %%
df_ps3.plot(x = 'combined_score', y = 'total_sales', kind = 'scatter', figsize=(16,5))
plt.show()

# %%
print('Critic score correlation:', '{:20.1%}'.format(df_ps3['critic_score'].corr(df_ps3['total_sales'])))
print('User score correlation:', '{:20.1%}'.format(df_ps3['user_score'].corr(df_ps3['total_sales'])))
print('Combined score correlation:', '{:20.1%}'.format(df_ps3['combined_score'].corr(df_ps3['total_sales'])))
# Out:
# Critic score correlation:                41.9%
# User score correlation:                 7.9%
# Combined score correlation:                27.6%

# %%
critic_corr = df_ps3.loc[:,'critic_score':'total_sales']
plt.subplots(figsize=(16,5))
sns.heatmap(critic_corr.corr())
plt.show()

# %%
display(df_ps4['critic_score'].describe())
print('-' *124)
display(df_ps4['user_score'].describe())
# Out:
# count    392.000000
# mean      70.975702
# std       10.115574
# min       19.000000
# 25%       68.967679
# 50%       68.967679
# 75%       77.000000
# max       97.000000
# Name: critic_score, dtype: float64
# ----------------------------------------------------------------------------------------------------------------------------
# count    392.000000
# mean       6.878013
# std        1.194475
# min        1.500000
# 25%        6.600000
# 50%        7.125046
# 75%        7.500000
# max        9.200000
# Name: user_score, dtype: float64

# %%
df_ps4.plot(x = 'combined_score', y = 'total_sales', kind = 'scatter', figsize=(16,5))
plt.show()

# %%
print('Critic score correlation:', '{:20.1%}'.format(df_ps4['critic_score'].corr(df_ps4['total_sales'])))
print('User score correlation:', '{:20.1%}'.format(df_ps4['user_score'].corr(df_ps4['total_sales'])))
print('Combined score correlation:', '{:20.1%}'.format(df_ps4['combined_score'].corr(df_ps4['total_sales'])))
# Out:
# Critic score correlation:                34.9%
# User score correlation:                -4.5%
# Combined score correlation:                15.6%

# %%
critic_corr = df_ps4.loc[:,'critic_score':'total_sales']
plt.subplots(figsize=(16,5))
sns.heatmap(critic_corr.corr())
plt.show()

# %% [markdown]
# Conclusion:
# > * Critics' score have a greater impact on sales than user score. But in general, score do not greatly affect sales, as the percentage does not exceed 42%.
# * Special case, PS4 platform: The percentages are even lower. 34% is the impact of the critics' score and the user score does not affect at all.

# %% [markdown]
# - [X] Keeping your conclusions in mind, compare the sales of the same games on other platforms.

# %%
# first need to create list of cross platform games: 
cross_plt_games = set(df_years_slice.groupby(['name']).filter(lambda x: x.shape[0] > 1)['name'])
display(cross_plt_games)
# Out:
# {'2014 FIFA World Cup Brazil',
#  'Jurassic: The Hunted',
#  'Gundam Breaker',
#  'Little Battlers eXperience W',
#  'Tiger Woods PGA Tour 12: The Masters',
#  'Jeopardy!',
#  "Cabela's North American Adventures",
#  'Making History: The Great War',
#  'Rock Band 2',
#  'Ghostbusters: The Video Game (DS Version)',
#  "Assassin's Creed: Revelations",
#  'Muramasa: The Demon Blade',
#  'Hitman: Absolution',
#  'One Piece: Romance Dawn - Bouken no Yoake',
#  "Jimmie Johnson's Anything With an Engine",
#  'Disney Infinity 3.0',
#  'Kingdoms of Amalur: Reckoning',
#  'The Beatles: Rock Band',
#  "Dragon Quest Heroes II: Twin Kings and the Prophecy's End",
#  'Tiger Woods PGA Tour 11',
#  "Backyard Baseball '09",
#  'Diablo III',
#  'Mortal Kombat',
#  'Puss in Boots',
#  'Toukiden Kiwami',
#  'WRC 5: FIA World Rally Championship',
#  'NHL 15',
#  'Barbie: Groom and Glam Pups',
#  'Battlefield: Bad Company 2',
#  'Sesame Street: Ready, Set, Grover!',
#  'Naruto Shippuden: Ultimate Ninja Storm 4',
#  'Captain Morgane and the Golden Turtle',
#  'LEGO Indiana Jones: The Original Adventures',
#  "NASCAR '14",
#  'Rock Band Country Track Pack 2',
#  'Puzzle Kingdoms',
#  'Pictionary',
#  'Sacred 3',
#  'Bratz: Girlz Really Rock',
#  'F1 2012',
#  'To Heart 2: Dungeon Travelers',
#  "Assassin's Creed Chronicles",
#  'Conflict: Denied Ops',
#  "Adventure Time: Explore the Dungeon Because I Don't Know!",
#  'Prison Break: The Conspiracy',
#  'WWE SmackDown vs. Raw 2009',
#  'MindJack',
#  "Shrek's Carnival Craze Party Games",
#  'Pro Evolution Soccer 2008',
#  'High School Musical 3: Senior Year DANCE!',
#  'MLB Power Pros 2008',
#  'Split/Second',
#  'Barbie and Her Sisters Puppy Rescue',
#  'Atari Flashback Classics: Volume 2',
#  'Injustice: Gods Among Us',
#  'Call of Duty: Modern Warfare Trilogy',
#  'Shin Megami Tensei: Devil Survivor 2',
#  'Rocksmith',
#  'Time Travelers',
#  "Chuck E. Cheese's Party Games",
#  'Harukanaru Toki no Naka de 6',
#  'Hail to the Chimp',
#  'Captain America: Super Soldier',
#  'Dungeon Siege III',
#  'Shovel Knight',
#  'Street Fighter X Tekken',
#  'MySims Kingdom',
#  'Guitar Hero: Aerosmith',
#  'Guitar Hero: Metallica',
#  'Arcana Heart 3',
#  'DJ Hero',
#  'Sébastien Loeb Rally Evo',
#  'Dream Pinball 3D',
#  'iCarly 2: iJoin The Click!',
#  'DanceDanceRevolution',
#  'Red Dead Redemption: Undead Nightmare',
#  'Senran Kagura: Estival Versus',
#  'Jikkyou Powerful Pro Yakyuu 2011 Ketteiban',
#  'Resident Evil 5',
#  "Sherlock Holmes: The Devil's Daughter",
#  'Nicktoons: MLB',
#  'Akatsuki no Goei Trinity',
#  'The Crew',
#  'ATV Quad Kings',
#  'Guitar Hero: Smash Hits',
#  'Aliens in the Attic',
#  'Batman: Arkham Asylum',
#  'PES 2009: Pro Evolution Soccer',
#  'Transformers: Revenge of the Fallen (XBox 360, PS3, & PC Versions)',
#  "Dragon's Dogma",
#  'WWE All Stars',
#  'Dream Salon',
#  'TNA iMPACT: Cross the Line',
#  'Space Invaders Extreme',
#  'PhotoKano',
#  'The Witcher 2: Assassins of Kings',
#  'Transformers: Prime',
#  'Fit in Six',
#  'Band Hero',
#  'Deadliest Catch: Sea of Chaos',
#  'Disney TH!NK Fast: The Ultimate Trivia Showdown',
#  'Far Cry 4',
#  'FIFA Soccer 13',
#  'Fallout 3',
#  'Yogi Bear: The Video Game',
#  'Rogue Warrior',
#  'LittleBigPlanet 3',
#  'The Penguins of Madagascar: Dr. Blowhole Returns - Again!',
#  'Michael Jackson: The Experience',
#  'Majin and the Forsaken Kingdom',
#  'Batman: Arkham Origins Blackgate',
#  'Grand Ages: Medieval',
#  'Ar Nosurge: Ode to an Unborn Star',
#  'Marvel Avengers: Battle for Earth',
#  'Sniper: Ghost Warrior',
#  'Hyrule Warriors',
#  'NHL 2K10',
#  'Anarchy Reigns',
#  'Winning Post 7 Maximum 2008',
#  'Scribblenauts Unmasked: A DC Comics Adventure',
#  'Need for Speed: Most Wanted',
#  'Need for Speed: The Run',
#  'Blood Drive',
#  'Summon Night 6: Lost Borders',
#  'Pro Evolution Soccer 2010',
#  'BlazBlue: Chrono Phantasma',
#  'James Bond 007: Blood Stone',
#  'Rock Band Track Pack: Classic Rock',
#  'DuckTales: Remastered',
#  'G-Force',
#  'Satisfashion',
#  'Drawn to Life: The Next Chapter',
#  'NASCAR 2011: The Game',
#  'Hysteria Hospital: Emergency Ward',
#  "JoJo's Bizarre Adventure: Eyes of Heaven",
#  'Challenge Me: Brain Puzzles 2',
#  'MotoGP 08',
#  'Sega Superstars Tennis',
#  'Ultimate Marvel vs. Capcom 3',
#  'Deus Ex: Human Revolution',
#  'Titanfall',
#  'Alone in the Dark',
#  'Chevrolet Camaro: Wild Ride',
#  'MLB 09: The Show',
#  'Hot Wheels: Track Attack',
#  'NASCAR The Game: Inside Line',
#  'Jikkyou Powerful Pro Yakyuu 15',
#  'Shaun White Skateboarding',
#  "Dora's Big Birthday Adventure",
#  'LEGO Batman: The Videogame',
#  'NPPL: Championship Paintball 2009',
#  'Ghostbusters (2016)',
#  'Wolfenstein: The Old Blood',
#  'Beijing 2008',
#  'One Piece: Pirate Warriors 3',
#  'NeverDead',
#  "Sid Meier's Civilization Revolution",
#  'Dragon Ball Z: Battle of Z',
#  'Lost Planet 3',
#  'Ghostbusters: The Video Game',
#  'SBK 2011: FIM Superbike World Championship',
#  'EA Sports MMA',
#  'Bass Pro Shops: The Hunt',
#  'Golden Axe: Beast Rider',
#  'MySims SkyHeroes',
#  "Assassin's Creed III",
#  '[Prototype 2]',
#  'Countdown: The Game',
#  'God Eater Resurrection',
#  'Dancing on Ice',
#  'Criminal Girls: Invite Only',
#  'Schlag den Raab',
#  'The Amazing Spider-Man (Console Version)',
#  "Mirror's Edge Catalyst",
#  'Skylanders Giants',
#  'Guitar Hero: World Tour',
#  'X-Blades',
#  'The Evil Within',
#  'Sniper: Ghost Warrior 2',
#  'MXGP 2',
#  'Gray Matter',
#  'Unchained Blades ',
#  'Penguins of Madagascar',
#  'Left 4 Dead 2',
#  'MX vs. ATV Reflex',
#  'Armored Core: For Answer',
#  'Heart no Kuni no Alice',
#  'NHL 17',
#  'LEGO Jurassic World',
#  'Rocksmith 2014 Edition Remastered',
#  'Middle-Earth: Shadow of Mordor',
#  'Spider-Man: Shattered Dimensions',
#  'Steins;Gate',
#  'Steins;Gate: Senkei Kousoku no Phonogram',
#  'Medal of Honor: Warfighter',
#  'WipeOut 3 The Game',
#  'Robotics;Notes',
#  'Tokyo Twilight Ghost Hunters',
#  'Sengoku Basara: Sanada Yukimura-Den',
#  'Thief (2014)',
#  'Iron Chef America: Supreme Cuisine',
#  'Bejeweled Twist',
#  'Yamaha Supercross',
#  'Little League World Series Baseball 2008',
#  'Tiger Woods PGA Tour 09',
#  'LEGO Dimensions',
#  'Football Manager 2012',
#  'Def Jam Rapstar',
#  'Monopoly Streets',
#  'Madden NFL 11',
#  'The Price is Right 2010 Edition',
#  'Grand Theft Auto V',
#  'Battlefield 1',
#  'Suzumiya Haruhi no Tsuisou',
#  'Inazuma Eleven 3',
#  'Jikkyou Powerful Pro Yakyuu 2011',
#  'F.E.A.R. 2: Project Origin',
#  'SafeCracker: The Ultimate Puzzle Adventure',
#  'Attack of the Movies 3D',
#  "Dragon's Crown",
#  'Prototype: Biohazard Bundle',
#  'SoulCalibur IV',
#  'Madden NFL 09',
#  'Gotouchi Tetsudou: Gotouchi Chara to Nihon Zenkoku no Tabi',
#  'NBA 2K14',
#  'Indiana Jones and the Staff of Kings',
#  'Paws & Claws: Pet Resort',
#  'Last Escort: Club Katze',
#  'Call of Duty: Black Ops 3',
#  'de Blob 2',
#  'TrackMania Turbo',
#  'Command & Conquer: Red Alert 3',
#  'The Godfather II',
#  'Batman: Arkham Knight',
#  'SBK X: Superbike World Championship',
#  'Pac-Man and the Ghostly Adventures 2',
#  'Minute to Win It',
#  "WWE '13",
#  'Just Cause 3',
#  'Lost Planet 2',
#  'Pro Evolution Soccer 2017',
#  'Killer is Dead',
#  'Fuel',
#  'Duke Nukem 3D: 20th Anniversary World Tour',
#  'Go Diego Go! Great Dinosaur Rescue',
#  "Sonic's Ultimate Genesis Collection",
#  'Super Robot Wars OG: The Moon Dwellers',
#  'Silent Hill: Shattered Memories',
#  'Final Fantasy Type-0',
#  'WWE 2K15',
#  'Dawn of Discovery',
#  'Space Chimps',
#  'AKB1/149: Love Election',
#  'The LEGO Movie Videogame',
#  'Chaos;Head Noah',
#  'Madden NFL 15',
#  'Ridge Racer Unbounded',
#  'Trials Fusion',
#  'Grand Theft Auto: Chinatown Wars',
#  'Biohazard: Revival Selection',
#  'Harvey Birdman: Attorney at Law',
#  'Shin Kamaitachi no Yoru: 11 Hitome no Suspect',
#  'Minecraft: Story Mode',
#  'Summer Challenge: Athletics Tournament',
#  'Madden NFL 25',
#  'Major League Baseball 2K9',
#  'Persona 5',
#  'Lightning Returns: Final Fantasy XIII',
#  "Casper's Scare School: Spooky Sports Day",
#  'Disney Infinity',
#  'Dynasty Warriors: Gundam Reborn',
#  'iCarly',
#  'Gummy Bears Mini Golf',
#  'Battlefield 4',
#  'Dark Souls III',
#  'Lego Star Wars: The Force Awakens',
#  'LEGO Indiana Jones 2: The Adventure Continues',
#  "Saint Seiya: Soldiers' Soul",
#  'James Bond 007: Legends',
#  'Test Drive: Ferrari Legends',
#  'Prince of Persia: The Forgotten Sands',
#  'SimCity Creator',
#  'Lords of the Fallen',
#  'Hatsune Miku: Project Diva X',
#  'Horse Life Adventures',
#  'Top Spin 4',
#  'Grand Slam Tennis 2',
#  'Moshi Monsters: Katsuma Unleashed',
#  'George of the Jungle and the Search for the Secret',
#  'Exist Archive: The Other Side of the Sky',
#  'Dead Space 2',
#  'Final Fantasy XIV: Heavensward',
#  'Fairytale Fights',
#  'Goldeneye 007: Reloaded',
#  'Persona 4: Arena Ultimax',
#  'NCAA Basketball 09',
#  'Tony Hawk: RIDE',
#  'Animal Planet: Vet Life',
#  'Atelier Totori: The Adventurer of Arland',
#  'Terminator Salvation',
#  'Just Cause 2',
#  'NHL 10',
#  " Frozen: Olaf's Quest",
#  'The Lord of the Rings: Conquest',
#  'World Soccer Winning Eleven 2010: Aoki Samurai no Chousen',
#  'Turok',
#  'Sword Art Online: Hollow Realization',
#  'Tomb Raider: Underworld',
#  'Max Payne 3',
#  'Hatsune Miku: Project Diva F 2nd',
#  'Pro Baseball Spirits 2015',
#  'Tetris Party Deluxe',
#  'Operation Flashpoint: Red River',
#  'Resident Evil 6',
#  'Overlord II',
#  'Blade Arcus from Shining EX',
#  'Etrian Odyssey II: Heroes of Lagaard',
#  'Destiny: The Taken King',
#  'LEGO Marvel Super Heroes',
#  'Wipeout: The Game',
#  "Grey's Anatomy: The Video Game",
#  'Jewel Master: Cradle Of Rome 2',
#  "You Don't Know Jack",
#  'Valentino Rossi: The Game',
#  'Rock Band 4',
#  "Cabela's Big Game Hunter: Pro Hunts",
#  '50 Classic Games',
#  'SNK Arcade Classics Vol. 1',
#  'Night at the Museum: Battle of the Smithsonian',
#  'The Saboteur',
#  'Dynasty Warriors 8: Empires',
#  'PDC World Championship Darts: Pro Tour',
#  'Tales of Hearts',
#  "Tom Clancy's Splinter Cell: Blacklist",
#  'Tekken Tag Tournament 2',
#  'UFC Personal Trainer: The Ultimate Fitness System',
#  'The Price is Right',
#  "Fist of the North Star: Ken's Rage 2",
#  'NBA 2K9',
#  'BlazBlue: Continuum Shift',
#  'The Adventures of Tintin: The Game',
#  'Super Robot Taisen OG Saga: Masou Kishin III - Pride of Justice',
#  "Tony Hawk's Pro Skater 5",
#  'NBA 2K13',
#  'DiRT Rally',
#  "Dragon's Dogma Online",
#  'Project CARS',
#  'Hyperdimension Neptunia',
#  'E.X. Troopers',
#  'Big League Sports: Summer',
#  'Tekken 6',
#  'Skylanders SWAP Force',
#  'Are You Smarter than a 5th Grader? Game Time',
#  'Arcania: Gothic 4',
#  'Rock Band 3',
#  'Karaoke Revolution Glee: Volume 3',
#  'Code Geass: Hangyaku no Lelouch - Lost Colors',
#  'Zero Escape: Zero Time Dilemma',
#  'Grand Theft Auto IV',
#  'Secret Agent Clank',
#  'Super Heroine Chronicle',
#  'Aliens: Colonial Marines',
#  'Pro Evolution Soccer 2012',
#  'The Club',
#  'WSC Real 11: World Snooker Championship',
#  'Marvel Super Hero Squad',
#  'Order Up!!',
#  'Angry Birds Trilogy',
#  'Pipe Mania',
#  'Utawarerumono: Futari no Hakuoro',
#  'Escape The Museum',
#  'The Legend of Heroes VII: The Trail of Blue',
#  'Dead Island',
#  'Sonic Unleashed',
#  'Mario & Sonic at the Rio 2016 Olympic Games',
#  'Wheel of Fortune',
#  'Guilty Gear Xrd -Revelator-',
#  'Get Up and Dance',
#  'Pictionary: Ultimate Edition',
#  'The Wolf Among Us',
#  'The Legend of Heroes: Trails in the Sky First Chapter',
#  'FIFA Street 3',
#  'Dragon Ball: XenoVerse',
#  'Sword Art Online: Lost Song',
#  'Dora The Explorer: Dora Saves the Snow Princess',
#  'One Piece: Burning Blood',
#  'UEFA Euro 2008 Austria-Switzerland',
#  'Family Game Night 4: The Game Show',
#  'Clannad',
#  'The Legend of Heroes: Trails of Cold Steel',
#  'Chaos;Child',
#  'uDraw Studio: Instant Artist',
#  'Bulletstorm',
#  'Family Guy: Back to the Multiverse',
#  'Jambo! Safari Animal Rescue',
#  'Are You Smarter than a 5th Grader? Make the Grade',
#  'The Tale of Despereaux',
#  'God of War III',
#  'Legends of WrestleMania',
#  "Sesame Street: Cookie's Counting Carnival",
#  'Sengoku Basara: Samurai Heroes',
#  "Margot's Word Brain",
#  'Rocksmith 2014',
#  'Dishonored 2',
#  'Clash of the Titans',
#  'Samurai Shodown Anthology',
#  'J Stars Victory Vs.',
#  'DreamWorks Super Star Kartz',
#  'Guilty Gear XX Accent Core Plus',
#  "Tom Clancy's EndWar",
#  "Skylanders: Spyro's Adventure",
#  "The Lord of the Rings: Aragorn's Quest",
#  'The Elder Scrolls V: Skyrim',
#  'LittleBigPlanet',
#  '2010 FIFA World Cup South Africa',
#  'FIFA 17',
#  'Castlevania: Lords of Shadow',
#  'Amnesia Later',
#  'Fallout 4',
#  'Rooms: The Main Building',
#  'Tales of Vesperia',
#  'NCAA Football 09',
#  'Busy Scissors',
#  'Bully: Scholarship Edition',
#  'Ben 10 Ultimate Alien: Cosmic Destruction',
#  'Minecraft',
#  'Monster High: Ghoul Spirit',
#  'The Incredible Hulk',
#  "Backyard NFL Football '09",
#  'Ben 10 Omniverse 2',
#  'Star Wars Battlefront: Elite Squadron',
#  'Ninja Reflex',
#  'Sonic Riders: Zero Gravity',
#  'Scribblenauts: Unlimited',
#  'I Am In The Movie',
#  'Disgaea 4: A Promise Unforgotten',
#  "John Daly's ProStroke Golf",
#  'Burnout Paradise',
#  'Agatha Christie: The ABC Murders',
#  'The Crew: Wild Run',
#  'Metal Gear Solid V: The Definitive Experience',
#  'Two Worlds II',
#  "Brothers in Arms: Hell's Highway",
#  "Shiren the Wanderer 4 - God's Eye and the Demon's Navel",
#  'Romance of the Three Kingdoms XII',
#  'Prison Architect',
#  'The Walking Dead: Season One',
#  'Castlevania: Lords of Shadow 2',
#  'Where the Wild Things Are',
#  'Sonic & All-Stars Racing Transformed',
#  'One Piece: Unlimited World Red',
#  'Operation Flashpoint: Dragon Rising',
#  'Turbo: Super Stunt Squad',
#  'Call of Duty: World at War',
#  'Baja: Edge of Control',
#  'Jikkyou Powerful Pro Yakyuu 2010',
#  'Onechanbara Z Kagura',
#  'Major League Baseball 2K13',
#  'CID The Dummy',
#  'Marvel Super Hero Squad: The Infinity Gauntlet',
#  'Cars: Race-O-Rama',
#  'Child of Light',
#  'Escape Dead Island',
#  'Battlefield: Bad Company',
#  'Danganronpa 2: Goodbye Despair',
#  'Natural Doctrine',
#  'Dynasty Warriors: Gundam 3',
#  'Supreme Commander 2',
#  'Moshi Monsters: Moshlings Theme Park',
#  'Winning Post 8 ',
#  'Ride',
#  'Centipede: Infestation',
#  'Venetica',
#  "Let's Play Ballerina",
#  'Who Wants to Be a Millionaire: 3rd Edition',
#  'Saw II: Flesh & Blood',
#  'Forza Horizon 2',
#  'LEGO The Lord of the Rings',
#  'Blitz: The League II',
#  'LEGO City Undercover',
#  'Call of Duty: Black Ops II',
#  'Crazy Machines',
#  'FIFA 14',
#  'Star Wars Battlefront (2015)',
#  'Kidou Senshi Gundam: Giren no Yabou - Axis no Kyoui V',
#  'Kung Fu Panda',
#  'Final Fantasy XIV: A Realm Reborn',
#  'Toy Soldiers: War Chest',
#  'MotoGP 14 ',
#  'Brink',
#  'Mega Man Legacy Collection',
#  "SpongeBob's Surf & Skate Roadtrip",
#  'Alvin and the Chipmunks: The Squeakquel',
#  "Assassin's Creed The Ezio Collection",
#  'Steins;Gate 0',
#  'Accel World: Kasoku no Chouten',
#  'World of Final Fantasy',
#  'Game of Thrones',
#  'Saints Row 2',
#  'Rise of the Tomb Raider',
#  'Puzzler Collection',
#  'SingStar Take That',
#  'ModNation Racers',
#  'Bakumatsu Rock: Ultra Soul',
#  'Monkey Island: Special Edition Collection',
#  'Military History: Commander - Europe at War',
#  'Aegis of Earth: Protonovus Assault',
#  'Divinity: Original Sin',
#  'Speed Racer: The Videogame',
#  'Lucha Libre AAA: Heroes del Ring',
#  'Fight Night Champion',
#  'Blades of Time',
#  'Batman: Return to Arkham',
#  'Destiny',
#  'Prince of Persia',
#  "SpongeBob's Boating Bash",
#  'Avatar: The Game',
#  'Call of Duty: Advanced Warfare',
#  'Rabbids Go Home',
#  'DJ Hero 2',
#  'BlazBlue: Calamity Trigger',
#  'Marvel: Ultimate Alliance 2',
#  'Mass Effect 3',
#  "Jumper: Griffin's Story",
#  'Painkiller: Hell & Damnation',
#  "Nobunaga's Ambition: Sphere of Influence - Sengoku Risshiden",
#  'Just Dance: Disney Party',
#  'NHL 14',
#  'Corpse Party: Blood Covered - Repeated Fear',
#  'Pony Friends 2',
#  'Sword Art Online: Hollow Fragment',
#  "Let's Dance with Mel B",
#  'LEGO Rock Band',
#  'Diva Girls: Divas on Ice',
#  'Murdered: Soul Suspect',
#  'Serious Sam HD: Gold Edition',
#  'Metal Gear Rising: Revengeance',
#  'UFC Undisputed 2010',
#  'Wolfenstein: The New Order',
#  'Adventure Time: Finn & Jake Investigations',
#  'Dynasty Warriors 7',
#  'NBA Live 16',
#  'Kung Fu Panda 2',
#  'Enemy Front',
#  'Metro: Last Light',
#  'Brunswick Pro Bowling',
#  'Naruto Shippuden: Ultimate Ninja Storm 2',
#  "Tom Clancy's The Division",
#  'Top Gun: Hard Lock',
#  'Tales of Zestiria',
#  'Odin Sphere: Leifthrasir',
#  'Destroy All Humans! Path of the Furon',
#  'FIFA Soccer 10',
#  'Transformers: Dark of the Moon',
#  'Borderlands 2',
#  'NBA 2K10',
#  'SCORE International Baja 1000: The Official Game',
#  'Toy Story 3: The Video Game',
#  'Legendary',
#  'Call of Duty: Modern Warfare 3',
#  'Call of Duty: Modern Warfare 2',
#  'Scooby-Doo! First Frights',
#  'Batman: The Brave and the Bold the Videogame',
#  'Kamen Rider: Battride War Genesis',
#  'Super Smash Bros. for Wii U and 3DS',
#  'Driver: San Francisco',
#  'Warriors Orochi 2',
#  'Virtua Tennis 4',
#  'Disney Sing It! High School Musical 3: Senior Year',
#  'EyePet',
#  "Dante's Inferno",
#  'XCOM: Enemy Unknown',
#  "Princess Isabella: A Witch's Curse",
#  'Epic Mickey 2: The Power of Two',
#  'Scrabble',
#  'Alice: Madness Returns',
#  'Puyo Puyo Tetris',
#  'Nitroplus Blasterz: Heroines Infinite Duel',
#  'Titanic Mystery',
#  'The Bureau: XCOM Declassified',
#  'Ben 10: Alien Force',
#  'Samurai Warriors 4: Empires',
#  'Need for Speed: Shift',
#  'Transformers: War for Cybertron (XBox 360, PS3, & PC Versions)',
#  'Hasbro Family Game Night Fun Pack',
#  'Knights in the Nightmare',
#  'Infinite Stratos 2: Ignition Hearts',
#  'Blur',
#  'Deer Drive',
#  'The Oregon Trail',
#  'Littlest Pet Shop',
#  'Dancing with the Stars: We Dance!',
#  'Birds of Steel',
#  'Rock Band Track Pack Volume 2',
#  'Ford Racing Off Road',
#  "Tom Clancy's Ghost Recon: Future Soldier",
#  'Scene It? Bright Lights! Big Screen!',
#  'Midnight Club: Los Angeles',
#  'Pro Yaky? Spirits 5',
#  'Dishonored',
#  'Sonic Lost World',
#  'F.E.A.R. 3',
#  'Rock Band Track Pack Volume 1',
#  'Avatar: The Last Airbender - Into the Inferno',
#  'Pure',
#  'Higurashi no Naku Koro ni Iki',
#  'Dragon Ball: Raging Blast',
#  '007: Quantum of Solace',
#  'WWE SmackDown vs. Raw 2010',
#  'Fallout: New Vegas',
#  'Supremacy MMA',
#  'Get Fit with Mel B',
#  'The Darkness II',
#  'TRON: Evolution',
#  'Ratchet & Clank Collection',
#  'Tropico 5',
#  'Pimp My Ride: Street Racing',
#  '7 Days to Die',
#  'WWE 2K14',
#  'Alice in Wonderland',
#  'The King of Fighters XII',
#  'NCIS',
#  'CSI: Deadly Intent',
#  "SpongeBob's Truth or Square",
#  'Castlevania: Lords of Shadow - Reverie',
#  'Monopoly',
#  'Rayman Raving Rabbids: TV Party',
#  'The Chronicles of Riddick: Assault on Dark Athena',
#  "Agatha Christie's The ABC Murders",
#  'Overwatch',
#  'Super Hero Generation',
#  'LEGO Pirates of the Caribbean: The Video Game',
#  'Call of Duty: Ghosts',
#  'Darksiders II',
#  "Tom Clancy's HAWX 2",
#  'Air Conflicts: Secret Wars',
#  'Hatsune Miku: Project Diva f',
#  'X-Men: Destiny',
#  'Winning Post 7 2013',
#  "Army of Two: The Devil's Cartel",
#  'The Princess and the Frog',
#  'Earth Defense Force 2: Invaders from Planet Space',
#  'Dynasty Warriors 6 Empires',
#  'Cloudy With a Chance of Meatballs',
#  'Naruto Shippuden: Ultimate Ninja Storm Generations',
#  'Wasteland 2',
#  'Diabolik Lovers: More Blood',
#  'Rango: The Video Game',
#  "The Peanuts Movie: Snoopy's Grand Adventure",
#  'Karaoke Revolution Presents American Idol Encore 2',
#  'Farm Frenzy 3',
#  'Back to the Future: The Game',
#  'The Smurfs 2',
#  'Shaun White Snowboarding',
#  "Legend of the Guardians: The Owls of Ga'Hoole",
#  'Family Feud: 2012 Edition',
#  'Viking: Battle for Asgard',
#  'My Ballet Studio',
#  'Ivy the Kiwi?',
#  'FIFA Soccer 09',
#  'Wanted: Weapons of Fate',
#  'Disney Sing It: Party Hits',
#  'Yoru no Nai Kuni',
#  'Winter Stars',
#  'Kyokugen Dasshutsu ADV: Zennin Shiboudesu',
#  'Deadliest Warrior: Ancient Combat',
#  'Midnight Mysteries: The Edgar Allan Poe Conspiracy',
#  'Legend of Kay',
#  'Winter Sports 2011',
#  "Deepak Chopra's Leela",
#  'SimAnimals',
#  'Ashes Cricket 2009',
#  'Turning Point: Fall of Liberty',
#  'NBA Live 14',
#  'Bass Pro Shops: The Strike',
#  'Dark Sector',
#  'Bigfoot: Collision Course',
#  "LEGO Legends of Chima: Laval's Journey",
#  'L.A. Noire',
#  'Disney Sing It: Pop Hits',
#  'Petz Rescue: Wildlife Vet',
#  'Pinball Hall of Fame: The Williams Collection',
#  'Rio',
#  'Gundam Breaker 2',
#  'Teenage Mutant Ninja Turtles: Mutants in Manhattan',
#  'Exstetra',
#  'FabStyle',
#  'Lost Heroes',
#  'Marvel vs. Capcom 3: Fate of Two Worlds',
#  'Bakugan: Battle Brawlers',
#  'Legend of Kay Anniversary',
#  'Saints Row: The Third',
#  'Attack on Titan (KOEI)',
#  'MotoGP 09/10',
#  'Need for Speed: Shift 2 Unleashed',
#  'Tiger Woods PGA Tour 13',
#  'Despicable Me: The Game',
#  'Madden NFL 13',
#  'Crysis 3',
#  "Akiba's Trip: Undead & Undressed",
#  'Rugby World Cup 2015',
#  'Final Fantasy XIII',
#  'BlazBlue: Continuum Shift II',
#  'Ninja Gaiden Sigma 2',
#  "Rubik's World",
#  'Igor: The Game',
#  'BioShock The Collection',
#  'Rock of the Dead',
#  'Conception II: Children of the Seven Stars',
#  'Don King Boxing',
#  'Borderlands',
#  'Game of Thrones (Telltale)',
#  'GRID 2',
#  'The Technomancer',
#  "LEGO Marvel's Avengers",
#  'The Price is Right: Decades',
#  'Tales of Berseria',
#  'UFC 2009 Undisputed',
#  'Monster Jam: Urban Assault',
#  'Secret Files: Tunguska',
#  'Chaos;Head - Love Chu*Chu!',
#  'Teenage Mutant Ninja Turtles: Smash-Up',
#  'Dynasty Warriors 8: Xtreme Legends',
#  'Final Fantasy X / X-2 HD Remaster',
#  'Backyard Sports: Sandlot Sluggers',
#  'Ferrari Challenge Trofeo Pirelli',
#  'Monster Jam: Path of Destruction',
#  'Utawarerumono: Itsuwari no Kamen',
#  'Toukiden 2',
#  'Natsuiro High School: Seishun Hakusho',
#  'FIFA 15',
#  'Bladestorm: Nightmare',
#  'The Walking Dead: Survival Instinct',
#  'Soccer Tsuku: Pro Soccer Club o Tsukurou!',
#  "Santa Claus Is Comin' to Town!",
#  'LEGO Star Wars III: The Clone Wars',
#  'Jonah Lomu Rugby Challenge',
#  'FIFA Soccer 11',
#  'The Mummy: Tomb of the Dragon Emperor',
#  'Science Papa',
#  'R.B.I. Baseball 2016',
#  'Dragon Quest X',
#  'Jewel Quest 5: The Sleepless Star',
#  'Madden NFL 16',
#  'Little League World Series Baseball 2010',
#  'MLB 12: The Show',
#  'Berserk and the Band of the Hawk',
#  'Rec Room Games',
#  'Sengoku Basara 3 Utage',
#  'LEGO Batman 2: DC Super Heroes',
#  'Hasbro Family Game Night',
#  'Star Wars: The Force Unleashed',
#  'Jikkyou Powerful Pro Baseball 2016',
#  'Hannah Montana: The Movie',
#  'Just Dance 2017',
#  'NCAA Football 13',
#  'Karaoke Revolution Presents American Idol Encore',
#  'Mark McMorris Infinite Air',
#  'Hitman: HD Trilogy',
#  'Skylanders: SuperChargers',
#  'Eat Lead: The Return of Matt Hazard',
#  'World of Zoo',
#  'Final Fantasy Crystal Chronicles: Echoes of Time',
#  'Rodea the Sky Soldier',
#  'Accel World: Ginyoku no Kakusei',
#  'F1 2009',
#  'Ace Combat: Assault Horizon',
#  'EA Sports UFC 2',
#  'Darksiders: Warmastered Edition',
#  'Dance on Broadway',
#  'Family Feud: 2010 Edition',
#  'Plants vs. Zombies: Garden Warfare 2',
#  'Monster Mayhem: Build and Battle',
#  'Dreamworks Madagascar Kartz',
#  'Press Your Luck 2010 Edition',
#  '3rd Super Robot Wars Z Jigoku Hen',
#  'Devil May Cry HD Collection',
#  'The Walking Dead: Season Two',
#  'Assetto Corsa',
#  'Winning Post 8 2015',
#  'Tomb Raider (2013)',
#  'Disney Infinity 2.0: Marvel Super Heroes',
#  'Shrek: Forever After',
#  'Pro Yaky? Spirits 2014',
#  'The Legend of Heroes VII: The Trail of Zero',
#  'Atelier Firis: The Alchemist of the Mysterious Journey',
#  'MX vs. ATV Supercross Encore',
#  'Atelier Ayesha: The Alchemist of Dusk',
#  'Alien: Isolation',
#  'DiRT 2',
#  'Ice Age: Dawn of the Dinosaurs',
#  'Amagami',
#  "Hell's Kitchen: The Game",
#  'DiRT 3',
#  'Ski-Doo Snowmobile Challenge',
#  'Deadpool',
#  'MySims Agents',
#  'Evolve',
#  'SingStar Queen',
#  'Tiger Woods PGA Tour 14',
#  'Singstar: Ultimate Party',
#  'Truth or Lies',
#  'Jaws: Ultimate Predator',
#  'Iron Man',
#  'NBA Live 10',
#  'White Album 2: Shiawase no Mukougawa',
#  "nail'd",
#  'Little League World Series Baseball: Double Play',
#  'Little League World Series Baseball 2009',
#  'Bionic Commando',
#  'Mortal Kombat X',
#  'SoulCalibur V',
#  'Sly Cooper: Thieves in Time',
#  "Cake Mania: Baker's Challenge",
#  'MotionSports: Adrenaline',
#  'Mario & Sonic at the Olympic Winter Games',
#  'Ragnarok Odyssey',
#  'GoldenEye 007 (2010)',
#  'Wonder World Amusement Park',
#  'NHL 09',
#  'Payday 2',
#  'Zoo Tycoon (2013)',
#  'MotoGP 10/11',
#  'Just Dance 4',
#  'Rayman Legends',
#  'Winter Sports 3: The Great Tournament',
#  "Cabela's Dangerous Hunts 2011",
#  'Fable III',
#  'Little Busters! Converted Edition',
#  'Earth Defense Force: Insect Armageddon',
#  'Life is Strange',
#  'Megamind: The Blue Defender',
#  'NHL 12',
#  'Red Faction: Guerrilla',
#  'The X-Factor',
#  'Horrid Henry: Missions of Mischief',
#  'Puyo Puyo!! 20th Anniversary',
#  'X-Men Origins: Wolverine - Uncaged Edition',
#  'Superstars V8 Racing',
#  'Doom 3 BFG Edition',
#  'Mass Effect Trilogy',
#  "Merv Griffin's Crosswords",
#  'Secret Files 2: Puritas Cordis',
#  'Sengoku Hime: Senran ni Mau Otometachi',
#  'Vin Diesel: Wheelman',
#  'Samurai Warriors: Sanada Maru',
#  'WRC 2: FIA World Rally Championship',
#  'EA Sports Active 2',
#  'Dragon Age II',
#  'Madden NFL 12',
#  'Dream C Club',
#  'Far Cry 3',
#  'Tenchu: Shadow Assassins',
#  'Lego Batman 3: Beyond Gotham',
#  'The Biggest Loser',
#  'Valkyria Chronicles',
#  'Dynasty Warriors: Gundam 2',
#  'Street Fighter V',
#  'Thomas & Friends: Hero of the Rails',
#  'Stormrise',
#  'Rock Blast',
#  'Rugby League Live 3',
#  'Fate/Extella: The Umbral Star',
#  'Mini Ninjas',
#  'Fast Food Panic',
#  'SD Gundam G Generation World',
#  'God Eater 2: Rage Burst',
#  'Zombie Army Trilogy',
#  'Skylanders: Trap Team',
#  'Persona 4: Arena',
#  'Street Fighter IV',
#  'The Legend of Heroes: Trails in the Sky Third Chapter',
#  'Young Justice: Legacy',
#  'Far Cry 2',
#  'Samurai Warriors 4-II',
#  'Star Wars: The Force Unleashed II',
#  'SpongeBob SquarePants featuring Nicktoons: Globs of Doom',
#  'Naruto Shippuden: Ultimate Ninja Storm 3',
#  'GRID Autosport',
#  'Dying Light',
#  'Tiger Woods PGA Tour 10',
#  'Thor: God of Thunder',
#  'NHL Legacy',
#  'All Kamen Rider: Rider Generation 2',
#  'Football Manager 2014',
#  'Warriors: Legends of Troy',
#  'The Witcher 3: Wild Hunt',
#  'Resonance of Fate',
#  'Dead to Rights: Retribution',
#  'Skate 2',
#  'Dragon Ball Z: Ultimate Tenkaichi',
#  "No More Heroes: Heroes' Paradise",
#  'Pro Yakyuu Spirits 5 Kanzenban',
#  'Need for Speed: Nitro',
#  "Cabela's Survival: Shadows of Katmai",
#  'PopStar Guitar',
#  'Burger Island',
#  'Teenage Mutant Ninja Turtles: Danger of the Ooze',
#  'The Black Eyed Peas Experience',
#  'The Legend of Spyro: Dawn of the Dragon',
#  'Bolt',
#  'Tak and the Guardians of Gross',
#  'Need for Speed (2015)',
#  'Watch Dogs 2',
#  'UnchainBlades EXXiV',
#  "Germany's Next Topmodel 2011",
#  'London 2012: The Official Video Game of the Olympic Games',
#  "Disney's Planes",
#  'Summer Athletics: The Ultimate Challenge',
#  'Dunamis 15',
#  'Green Day: Rock Band',
#  'Champion Jockey: G1 Jockey & Gallop Racer',
#  'SD Gundam G Generation Wars',
#  'F1 2016 (Codemasters)',
#  'Dynasty Warriors 8',
#  'Monster High: New Ghoul in School',
#  "Cabela's Outdoor Adventures (2009)",
#  'Binary Domain',
#  'Rock Revolution',
#  "Hunted: The Demon's Forge",
#  'Metal Gear Solid V: Ground Zeroes',
#  'El Shaddai: Ascension of the Metatron',
#  'Atelier Meruru: Alchemist of Arland 3',
#  'Disney Universe',
#  'Pro Evolution Soccer 2016',
#  'Apache: Air Assault',
#  'Omerta: City of Gangsters',
#  'The Amazing Spider-Man 2 (2014)',
#  'Detective Conan: Prelude from the Past',
#  'BlazBlue: Chrono Phantasma Extend',
#  'The Chronicles of Narnia: Prince Caspian',
#  'Transformers: Fall of Cybertron',
#  'Sacred 2: Fallen Angel',
#  'Dragon Age: Origins',
#  'Root Letter',
#  'Greg Hastings Paintball 2',
#  'Xblaze: Lost Memories',
#  'Digimon All-Star Rumble',
#  'Need For Speed: Undercover',
#  'NASCAR Heat Evolution',
#  "Assassin's Creed Syndicate",
#  'Dead or Alive 5',
#  'Jikkyou Powerful Pro Yakyuu 2014',
#  'Alvin and the Chipmunks: Chipwrecked',
#  'Skylanders Imaginators',
#  'Need for Speed Rivals',
#  'BlazBlue Central Fiction',
#  'Sakura-Sou no Pet na Kanojo',
#  'Hitman (2016)',
#  'The Sims 3',
#  'Yakuza Zero: The Place of Oath',
#  'Battlefield: Hardline',
#  'CSI: Fatal Conspiracy',
#  'Grease Dance',
#  'Big League Sports',
#  'SimAnimals Africa',
#  'Dark Souls',
#  'Armored Core V',
#  'Spec Ops: The Line',
#  'Pro Yaky? Spirits 2011',
#  'Trine 2',
#  "SpongeBob SquarePants: Plankton's Robotic Revenge",
#  'Fantasia: Music Evolved',
#  'Raven Squad: Operation Hidden Dagger',
#  'Fight Night Round 4',
#  "Assassin's Creed IV: Black Flag",
#  'SSX',
#  'Atelier Rorona: Alchemist of Arland',
#  'NCAA Basketball 10',
#  'Psycho-Pass: Mandatory Happiness',
#  'Silent Hill HD Collection',
#  'Chicken Blaster',
#  "Asura's Wrath",
#  'Risen 2: Dark Waters',
#  'Up',
#  'Guilty Gear Xrd: Sign',
#  'NBA 09: The Inside',
#  'Bodycount',
#  "Let's Play Garden",
#  'Bratz Kidz',
#  'pro evolution soccer 2011',
#  'Major League Baseball 2K12',
#  'My Baby: First Steps',
#  'Man vs. Wild',
#  'Family Fortunes',
#  'Hidden Mysteries: Titanic - Secrets of the Fateful Voyage',
#  'Medal of Honor',
#  'Brothers: A Tale of Two Sons',
#  'SAW',
#  'Red Faction: Armageddon',
#  'Handball 16',
#  'Gundam Breaker 3',
#  'Deus Ex: Mankind Divided',
#  'NBA 2K11',
#  'SingStar Motown',
#  'MLB 14: The Show',
#  'Just Dance Kids 2',
#  'My Horse & Me: Riding for Gold',
#  'Warhammer 40,000: Space Marine',
#  'Quantum Break',
#  ...}

# %%
df_pop_games = df_years_slice.query('name in @cross_plt_games').groupby(['name', 'platform']).agg({'total_sales' : 'sum'})
df_pop_games.sort_values(by='total_sales', ascending=False, inplace=True)

# %%
# total sales more than 6 millions dollars. 
df_pop_games.query('total_sales > 6.0').head(10)
# Out:
#                                          total_sales
# name                           platform
# Grand Theft Auto V             PS3             21.05
#                                X360            16.27
# Call of Duty: Modern Warfare 3 X360            14.73
# Call of Duty: Black Ops 3      PS4             14.63
# Call of Duty: Black Ops        X360            14.62
# Call of Duty: Black Ops II     PS3             13.79
#                                X360            13.68
# Call of Duty: Modern Warfare 2 X360            13.47
# Call of Duty: Modern Warfare 3 PS3             13.33
# Call of Duty: Black Ops        PS3             12.63

# %% [markdown]
# > * Conclusion: the most popular games (in terms of sales) are presented for platforms Microsoft Xbox 360 and Sony Play Station (PS3 and PS4 versions).

# %% [markdown]
# - [X] Take a look at the general distribution of games by genre. What can we say about the most profitable genres? Can you generalize about genres with high and low sales?

# %%
# take a look first again to dataframe df_years_slices.
df_years_slice.head()
# Out:
#                          name platform  year_of_release     genre  na_sales  \
# 2              Mario Kart Wii      Wii             2008    Racing     15.68
# 3           Wii Sports Resort      Wii             2009    Sports     15.61
# 8   New Super Mario Bros. Wii      Wii             2009  Platform     14.44
# 14         Kinect Adventures!     X360             2010      Misc     15.00
# 15               Wii Fit Plus      Wii             2009    Sports      9.01
#
#     eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 2      12.76      3.79         3.29          82.0         8.3      E
# 3      10.93      3.28         2.95          80.0         8.0      E
# 8       6.94      4.70         2.24          87.0         8.4      E
# 14      4.89      0.24         1.69          61.0         6.3      E
# 15      8.49      2.53         1.77          80.0         7.4      E
#
#     total_sales
# 2         35.52
# 3         32.77
# 8         28.32
# 14        21.82
# 15        21.80

# %%
genres = df_years_slice.groupby('genre').agg({'total_sales':'sum'}).sort_values(by='total_sales', ascending=False)
display(genres)
# Out:
#               total_sales
# genre
# Action             945.74
# Shooter            608.19
# Sports             560.34
# Role-Playing       421.57
# Misc               396.43
# Racing             226.41
# Platform           195.38
# Simulation         150.78
# Fighting           148.51
# Adventure          105.86
# Strategy            59.73
# Puzzle              55.62

# %%
# render above data about genres in plot: 
ax = genres.plot(kind='bar', y='total_sales', title='total_sales vs. genres', figsize=(16,5))
for i in ax.patches: 
    ax.annotate(str(round(i.get_height(), 1)), (i.get_x() * 1, i.get_height() * 1.05))

# %%
# double check year_of_release column:
df_years_slice['year_of_release']
# Out:
# 2        2008
# 3        2009
# 8        2009
# 14       2010
# 15       2009
#          ...
# 16707    2014
# 16709    2008
# 16710    2016
# 16712    2016
# 16714    2016
# Name: year_of_release, Length: 8130, dtype: int32

# %%
# additional interpretation of data on popular genres starting from 2008.
for year in [2008 + i for i in range(9)]:
    render_plot_bar(df_years_slice, 'genre', 'total_sales', column='year_of_release', value=year, func='count')

# %% [markdown]
# > * Conclusion:
#     * The most popular genre of the game is the genre - Action. (Throughout the entire sample for the year, from 2008 to 2016).
#     * The second and third places were usually taken by genres - "Misc" and "Sports", respectively. (Based on data from 2008 to 2011.)
#     * The situation changed in 2012, when the genre of "Misc" gave way to the genre -"Role-Playing" games, the third place was mainly held by the genre - "Sports".
#     * Special case - PS4 platform: game Call of Duty: Black Ops 3 has a genre action.

# %% [markdown]
# ### Step 4. Create User Profile for each region <a name="#Step4UserProfile"></a>

# %% [markdown]
# #### To-Do List: <a name="#Step4ToDoList"></a>

# %% [markdown]
# > - [x] For each region (NA, EU, JP), determine:
# - [X] The top five platforms. Describe variations in their market shares from region to region.
# - [X] The top five genres. Explain the difference.
# - [X] Do ESRB ratings affect sales in individual regions?

# %%
regions = ['na_sales','eu_sales','jp_sales', 'other_sales']

for region in regions:
    print("Region is:", region.title())
    display(df_years_slice.pivot_table(index='platform', values=region, aggfunc='sum').sort_values(by=region, ascending=False).head())
    display(df_years_slice.pivot_table(index='genre', values=region, aggfunc='sum').sort_values(by=region, ascending=False).head())
    display(df_years_slice.pivot_table(index='rating', values=region, aggfunc='sum').sort_values(by=region, ascending=False).head())
# Out:
# Region is: Na_Sales
#           na_sales
# platform
# X360        595.57
# Wii         496.90
# PS3         393.49
# DS          326.08
# PS2         125.81
#               na_sales
# genre
# Action          546.28
# Sports          409.87
# Shooter         380.54
# Misc            292.76
# Role-Playing    200.40
#         na_sales
# rating
# E         938.52
# M         611.60
# T         571.16
# E10+      323.22
# EC          1.32
# Region is: Eu_Sales
#           eu_sales
# platform
# PS3         330.29
# X360        270.33
# Wii         262.21
# DS          143.47
# PS4         141.09
#          eu_sales
# genre
# Action     358.84
# Sports     257.01
# Shooter    241.71
# Misc       149.02
# Racing     115.41
#         eu_sales
# rating
# E         592.38
# M         424.96
# T         324.52
# E10+      178.52
# RP          0.08
# Region is: Jp_Sales
#           jp_sales
# platform
# DS          142.04
# 3DS         100.67
# PS3          80.19
# PSP          71.53
# Wii          69.33
#               jp_sales
# genre
# Role-Playing    172.40
# Action          103.36
# Misc             65.62
# Sports           49.58
# Platform         35.32
#         jp_sales
# rating
# T         256.23
# E         228.09
# M          47.12
# E10+       36.57
# EC          0.00
# Region is: Other_Sales
#           other_sales
# platform
# PS3            135.68
# X360            85.12
# Wii             79.07
# PS2             71.67
# PS4             48.35
#               other_sales
# genre
# Action             135.82
# Sports              98.99
# Shooter             86.45
# Misc                59.68
# Role-Playing        41.99
#         other_sales
# rating
# E            206.29
# M            150.43
# T            135.70
# E10+          69.14
# EC             0.08

# %% [markdown]
# Conclusion:
# > * Xbox360 is the most popular platform in North America (na_sales):
#     * Action is the most popular genre; Sports next.
#     * E rating is the most popular rating, closely followed by M.
# * In Europe (eu_sales), most popular platform - PlayStation3.
#     * Action is the most popular as well.
#     * E rating is the most raiting followed by M.
# * In Japan (jp_sales), most popular platform - 3DS.
#     * Role-Playing is larger that Action genre in Japan.
#     * T - most popular rating in Japan.

# %% [markdown]
# ### Step 5. Test the following Hypotheses <a name="#Step5Hypotheses"></a>

# %% [markdown]
# #### To-Do List: <a name="Step5ToDoList"></a>

# %% [markdown]
# > - [X] Average user ratings of the Xbox One and PC platforms are the same.
# - [X] Average user ratings for the Action and Sports genres are different.
#       Note: Set the alpha threshold value yourself.
# Explain:
# - [X] How you formulated the null and alternative hypotheses
# - [X] What significance level you chose to test the hypotheses, and why

# %% [markdown]
# **Null Hypotheses: The average user ratings of the Xbox One and PC platforms are the same:**
# > * Condition for check: (XboxOne_rating_mean) == (PC_rating_mean)

# %% [markdown]
# **Alternative Hypotheses: The average user ratings of the Xbox One and PC platforms are not the same:**
# > * Condition for check: (XboxOne_rating_mean) != (PC_rating_mean)

# %%
xbox_one_user = df_years_slice.query('platform == "XOne"')['user_score']
pc_user       = df_years_slice.query('platform == "PC"')['user_score']

print('Xbox One platform mean value:', xbox_one_user.mean())
print('PC platform mean value:',pc_user.mean())
# Out:
# Xbox One platform mean value: 6.680275292975524
# PC platform mean value: 6.807978517607474

# %%
# define function for check hypotheses:
def test_hypotheses(pattern_1, pattern_2):
    alpha   = .05
    results = st.ttest_ind(pattern_1, pattern_2)

    print('pvalue:', results.pvalue)
    print('alpha:', alpha)
    if results.pvalue < alpha:
        print('Decision: We reject the null hypotheses')
    else:
        print('Decision: We cannot reject the null hypotheses')

# %%
test_hypotheses(xbox_one_user, pc_user)
# Out:
# pvalue: 0.1969635664589852
# alpha: 0.05
# Decision: We cannot reject the null hypotheses

# %% [markdown]
# > * The mean user_score for the these two platforms are very similar to each other. By using the ttest, we can confirm that we cannot to reject the null hypotheses.

# %% [markdown]
# **Null Hypotheses: Average user ratings for the Action and Sports genres are equal :**
# > * Condition for check: (action_mean) == (sports_mean)

# %% [markdown]
# **Null Hypotheses: Average user ratings for the Action and Sports genres are not equal:**
# > * Condition for check: (action_mean) != (sports_mean)

# %%
action_user = df_years_slice.query('genre == "Action"')['user_score']
sports_user = df_years_slice.query('genre == "Sports"')['user_score']

print('Action genre mean value:', action_user.mean())
print('Sports genre mean value:', sports_user.mean())
# Out:
# Action genre mean value: 6.978039170464331
# Sports genre mean value: 6.652422977162005

# %%
test_hypotheses(action_user, sports_user)
# Out:
# pvalue: 1.188578146168737e-13
# alpha: 0.05
# Decision: We reject the null hypotheses

# %% [markdown]
# > * Based on the fact that the Null hypothesis was **REJECTED**, it can be **CONFERMED** that the alternative hypothesis that "the average user ratings for the Action and Sports genres are not equal - **DIFFERENT**."

# %% [markdown]
# ### Step 6. Write general conclusion <a name="GeneralConclusion"></a>

# %% [markdown]
# > * There are many missing values in the initial project datasets. Largest percentage of missing values in critics, user scores, and ratings. I believe that the main reason is that some do not rate them as this is not the main reason for them to buy the game. Only the best or worst games can be judged from the users' point of view. The reason for the presence of a large number of missing values among the critics is not clear to me. It is worth taking the time to find out this reason.
# * After about 1 year, the console will gain popularity. Typical lifespan of concolse is around 4-6 years.
# * The most popular genre of the game is the genre - Action. (Throughout the entire sample for the year, from 2008 to 2016).
# The second and third places were usually taken by genres - "Misc" and "Sports", respectively. (Based on data from 2008 to 2011.)
# * North America: Xbox360 is the most popular platform in North America. Action is the most popular genre; Sports next. E rating is the most popular rating, closely followed by M.
# * In Europe: most popular platform - PlayStation3. Action is the most popular as well. E rating is the most raiting followed by M.
# In Japan: most popular platform - 3DS. Role-Playing is larger that Action genre in Japan. T - most popular rating in Japan.

# %% [markdown]
# **Suggestions:**
# > * Ice company should pay attention to sales of the game on the XBox and Sony PlayStation platforms. Also, taking into account the geographic specifics. This is very important, since, for example, in Japan, in contrast to America and Europe, the genre of role-playing games is not very popular.
# * Сoncentrate on the genre of sales - action, sports and role-playing games.
# * Additionally, you can advise the introduction of various monthly subscriptions, which can keep the flow of money from users. At the moment, the market for released platforms is becoming more and more conservative and includes 4-5 popular platforms.
# * Additionally, you can make a promotion for games for old platforms, for those who still have old platforms.
